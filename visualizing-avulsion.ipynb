# %%
import matplotlib.pyplot as plt
import scipy.io
import numpy as np

# %%
ax = plt.figure().add_subplot(projection='3d')

# Recursive function for plotting the tree - just pass the head node and color
def plot_nodes(node, color):
    if 'children' in node:
        for i in range(len(node['children'])):
            child = node['children'][i]
            ax.plot([node['location'][0], child['location'][0]], [node['location'][1], child['location'][1]], [node['location'][2], child['location'][2]], color)
            plot_nodes(child, color)

# %%
bed_elevations = scipy.io.loadmat('data/4.mat')['eta_save']
frames = []
for i in range(bed_elevations.shape[1]):
    bed_elevation = bed_elevations[:, i]
    
    # Position nodes in a cantor set in a 2D plane (manually for 7 nodes)
    frames.append(
        {
            "location": [1/2,0, bed_elevation[0]],
            "children": [
                    {
                        "location": [1/6, 1/2, bed_elevation[1]],
                        "children": [
                            {
                                "location": [1/18, 1, bed_elevation[3]]
                            },
                            {
                                "location": [4/18, 1, bed_elevation[4]]
                            }
                        ]
                    },
                    {
                        "location": [5/6, 1/2, bed_elevation[2]],
                        "children": [
                            {
                                "location": [14/18, 1, bed_elevation[5]]
                            },
                            {
                                "location": [17/18, 1, bed_elevation[6]]
                            }
                        ]
                    }
             ]
        }
    )
times = scipy.io.loadmat('data/4.mat')['t_save'][0]

# %%
ax = plt.figure().add_subplot(projection='3d')
ax.view_init(elev=20., azim=45, roll=0)

ax.set_xlabel('$y$')
ax.set_ylabel('$x$')
ax.set_zlabel('Bed Elevation $\eta$ (meters)')
ax.set_zlim(20, 26)
plot_nodes(frames[-1], 'b')
ax.set_title(f'$t$ = {np.round(times[-1],2)} years', y=-.08)
plt.show()

# %%
for i in list(np.linspace(0,bed_elevations.shape[1], 500)):
    i = int(i)
    if i < len(frames):
        ax = plt.figure().add_subplot(projection='3d')
        ax.view_init(elev=20., azim=45, roll=0)

        ax.set_xlabel('$y$')
        ax.set_ylabel('$x$')
        ax.set_zlabel('Bed Elevation $\eta$ (meters)')
        ax.set_zlim(20, 26)
        plot_nodes(frames[i], 'b')
        ax.set_title(f'$t$ = {np.round(times[i],2)} years', y=-.08)
        plt.savefig(f'frames/{str(i).zfill(5)}.png')
        print(i/len(frames), flush=True)
        plt.close()
# Out:
# 0.0
# 0.002
# 0.004
# 0.006
# 0.008
# 0.01
# 0.012
# 0.014
# 0.016
# 0.018
# 0.02
# 0.022
# 0.024
# 0.02605
# 0.02805
# 0.03005
# 0.03205
# 0.03405
# 0.03605
# 0.03805
# 0.04005
# 0.04205
# 0.04405
# 0.04605
# 0.04805
# 0.0501
# 0.0521
# 0.0541
# 0.0561
# 0.0581
# 0.0601
# 0.0621
# 0.0641
# 0.0661
# 0.0681
# 0.0701
# 0.0721
# 0.0741
# 0.07615
# 0.07815
# 0.08015
# 0.08215
# 0.08415
# 0.08615
# 0.08815
# 0.09015
# 0.09215
# 0.09415
# 0.09615
# 0.09815
# 0.1002
# 0.1022
# 0.1042
# 0.1062
# 0.1082
# 0.1102
# 0.1122
# 0.1142
# 0.1162
# 0.1182
# 0.1202
# 0.1222
# 0.1242
# 0.12625
# 0.12825
# 0.13025
# 0.13225
# 0.57915
# 0.58115
# 0.58315
# 0.58515
# 0.58715
# 0.58915
# 0.59115
# 0.59315
# 0.59515
# 0.59715
# 0.59915
# 0.6012
# 0.6032
# 0.6052
# 0.6072
# 0.6092
# 0.6112
# 0.6132
# 0.6152
# 0.6172
# 0.6192
# 0.6212
# 0.6232
# 0.62525
# 0.62725
# 0.62925
# 0.63125
# 0.63325
# 0.63525
# 0.63725
# 0.63925
# 0.64125
# 0.64325
# 0.64525
# 0.64725
# 0.64925
# 0.6513
# 0.6533
# 0.6553
# 0.6573
# 0.6593
# 0.6613
# 0.6633
# 0.6653
# 0.6673
# 0.6693
# 0.6713
# 0.6733
# 0.67535
# 0.67735
# 0.67935
# 0.68135
# 0.68335
# 0.68535
# 0.68735
# 0.68935
# 0.69135
# 0.69335
# 0.69535
# 0.69735
# 0.69935
# 0.7014
# 0.7034
# 0.7054
# 0.7074
# 0.7094
# 0.7114
# 0.7134
# 0.7154
# 0.7174
# 0.7194
# 0.7214
# 0.7234
# 0.72545
# 0.72745
# 0.72945
# 0.73145
# 0.73345
# 0.73545
# 0.73745
# 0.73945
# 0.74145
# 0.74345
# 0.74545
# 0.74745
# 0.74945
# 0.7515
# 0.7535
# 0.7555
# 0.7575
# 0.7595
# 0.7615
# 0.7635
# 0.7655
# 0.7675
# 0.7695
# 0.7715
# 0.7735
# 0.77555
# 0.77755
# 0.77955
# 0.78155
# 0.78355
# 0.78555
# 0.78755
# 0.78955
# 0.79155
# 0.79355
# 0.79555
# 0.79755
# 0.79955
# 0.8016
# 0.8036
# 0.8056
# 0.8076
# 0.8096
# 0.8116
# 0.8136
# 0.8156
# 0.8176
# 0.8196
# 0.8216
# 0.8236
# 0.82565
# 0.82765
# 0.82965
# 0.83165
# 0.83365
# 0.83565
# 0.83765
# 0.83965
# 0.84165
# 0.84365
# 0.84565
# 0.84765
# 0.84965
# 0.8517
# 0.8537
# 0.8557
# 0.8577
# 0.8597
# 0.8617
# 0.8637
# 0.8657
# 0.8677
# 0.8697
# 0.8717
# 0.8737
# 0.87575
# 0.87775
# 0.87975
# 0.88175
# 0.88375
# 0.88575
# 0.88775
# 0.88975
# 0.89175
# 0.89375
# 0.89575
# 0.89775
# 0.89975
# 0.9018
# 0.9038
# 0.9058
# 0.9078
# 0.9098
# 0.9118
# 0.9138
# 0.9158
# 0.9178
# 0.9198
# 0.9218
# 0.9238
# 0.92585
# 0.92785
# 0.92985
# 0.93185
# 0.93385
# 0.93585
# 0.93785
# 0.93985
# 0.94185
# 0.94385
# 0.94585
# 0.94785
# 0.94985
# 0.9519
# 0.9539
# 0.9559
# 0.9579
# 0.9599
# 0.9619
# 0.9639
# 0.9659
# 0.9679
# 0.9699
# 0.9719
# 0.9739
# 0.97595
# 0.97795
# 0.97995
# 0.98195
# 0.98395
# 0.98595
# 0.98795
# 0.98995
# 0.99195
# 0.99395
# 0.99595
# 0.99795

# %%
# Bash command for animation
# ffmpeg -framerate 30 -pattern_type glob -i 'frames/*.png' -pix_fmt yuv420p avulsion.mp4
